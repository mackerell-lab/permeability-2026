# %%
from glob import glob
from analysis_utlis import *
from other_utlis import *

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ### P_app prediction with Hybrid  vs explicit LGFE profiles

# %% [markdown]
# ### 1. For BBB models

# %%
memb_csv_files = [["../ml-modeling-P_app_lgfe_biogen_base/evaluation/XGBoost/evaluation_bbb.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/XGBoost/evaluation_bbb.csv",
                  "../ml-modeling-P_app_lgfe_biogen_base/evaluation/LightGBM/evaluation_bbb.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/LightGBM/evaluation_bbb.csv",
                  "../ml-modeling-P_app_lgfe_biogen_base/evaluation/FCNN-1/evaluation_bbb.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/FCNN-1/evaluation_bbb.csv"]]
for csv_file in memb_csv_files:
    df = concat_metric_files(csv_file)
    # print (df.head())
    metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
    levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
    print (Path(csv_file[0]).name)
    print (levene_variance_df)
    metric_ls = ['PearsonR', 'RMSE', 'MAE']
    split_ls = ['scaffold', 'butina'] #, 'random']
    for split in split_ls:
        make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_bbb_P_app_protomers", common_prefix="bbb-biogen-P_app")
        make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_bbb_P_app_protomers", common_prefix="bbb-biogen-P_app")
# Out:
# evaluation_bbb.csv
#        split       metric  levene_pvalue   max_over_min
# 0     butina           R2       0.004977       5.492935
# 1     butina         RMSE       0.798716       1.955821
# 2     butina          MAE       0.275453       3.301335
# 3     butina     PearsonR       0.005461       4.208785
# 4     butina  SpearmanRho       0.047426       2.776250
# 5     random           R2       0.034787       4.251702
# 6     random         RMSE       0.986280       1.441267
# 7     random          MAE       0.400936       2.534257
# 8     random     PearsonR       0.028859       4.802033
# 9     random  SpearmanRho       0.052304       6.195617
# 10  scaffold           R2       0.000843  334278.677720
# 11  scaffold         RMSE       0.000085    6867.605456
# 12  scaffold          MAE       0.000011      15.410755
# 13  scaffold     PearsonR       0.000035     191.912737
# 14  scaffold  SpearmanRho       0.046228       6.247806

# %%
memb_csv_files = [["../ml-modeling-P_app_lgfe_biogen_base/evaluation/XGBoost/evaluation_pampa.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/XGBoost/evaluation_pampa.csv",
                  "../ml-modeling-P_app_lgfe_biogen_base/evaluation/LightGBM/evaluation_pampa.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/LightGBM/evaluation_pampa.csv",
                  "../ml-modeling-P_app_lgfe_biogen_base/evaluation/FCNN-1/evaluation_pampa.csv",
                   "../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/FCNN-1/evaluation_pampa.csv"]]
for csv_file in memb_csv_files:
    df = concat_metric_files(csv_file)
    # print (df.head())
    metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
    levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
    print (Path(csv_file[0]).name)
    print (levene_variance_df)
    metric_ls = ['PearsonR', 'RMSE', 'MAE']
    split_ls = ['scaffold', 'butina'] #, 'random']
    for split in split_ls:
        make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_pampa_P_app_protomers", common_prefix="pampa-biogen-P_app")
        make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_pampa_P_app_protomers", common_prefix="pampa-biogen-P_app")
# Out:
# evaluation_pampa.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2       0.001835   3146.302019
# 1     butina         RMSE       0.000593    413.609447
# 2     butina          MAE       0.030858      4.177411
# 3     butina     PearsonR       0.000003     53.230607
# 4     butina  SpearmanRho       0.299596      2.406525
# 5     random           R2       0.047899      3.635424
# 6     random         RMSE       0.960408      1.264944
# 7     random          MAE       0.244898      2.456938
# 8     random     PearsonR       0.025219      4.310215
# 9     random  SpearmanRho       0.002713      7.959456
# 10  scaffold           R2       0.000912     11.407648
# 11  scaffold         RMSE       0.013963      3.918004
# 12  scaffold          MAE       0.110468      2.905404
# 13  scaffold     PearsonR       0.000269      9.735233
# 14  scaffold  SpearmanRho       0.042393      3.267407

# %%
memb_csv_files = [["../ml-modeling-ER_lgfe_biogen_base/evaluation/XGBoost/evaluation_bbb.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/XGBoost/evaluation_bbb.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/LightGBM/evaluation_bbb.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/LightGBM/evaluation_bbb.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/FCNN-1/evaluation_bbb.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/FCNN-1/evaluation_bbb.csv"]]
for csv_file in memb_csv_files:
    df = concat_metric_files(csv_file)
    # print (df.head())
    metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
    levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
    print (Path(csv_file[0]).name)
    print (levene_variance_df)
    metric_ls = ['PearsonR', 'RMSE', 'MAE']
    split_ls = ['scaffold', 'butina'] #, 'random']
    for split in split_ls:
        make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_bbb_ER_protomers", common_prefix="bbb-biogen-ER")
        make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_bbb_ER_protomers", common_prefix="bbb-biogen-ER")
# Out:
# evaluation_bbb.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2   3.752212e-02  5.163428e+00
# 1     butina         RMSE   3.326478e-05  9.255443e+00
# 2     butina          MAE   7.983219e-03  4.897806e+00
# 3     butina     PearsonR   2.472802e-01  3.369142e+00
# 4     butina  SpearmanRho   2.179778e-07  1.549323e+01
# 5     random           R2   3.341749e-02  3.322697e+00
# 6     random         RMSE   6.523395e-03  3.912999e+00
# 7     random          MAE   9.203341e-03  3.385134e+00
# 8     random     PearsonR   2.829391e-01  2.040869e+00
# 9     random  SpearmanRho   1.031955e-01  2.447468e+00
# 10  scaffold           R2   7.649094e-03  2.832173e+07
# 11  scaffold         RMSE   5.572895e-04  4.867607e+04
# 12  scaffold          MAE   1.264287e-04  1.906948e+02
# 13  scaffold     PearsonR   1.879849e-04  2.314381e+02
# 14  scaffold  SpearmanRho   1.594473e-01  3.561809e+00

# %%
memb_csv_files = [["../ml-modeling-ER_lgfe_biogen_base/evaluation/XGBoost/evaluation_pampa.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/XGBoost/evaluation_pampa.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/LightGBM/evaluation_pampa.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/LightGBM/evaluation_pampa.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/FCNN-1/evaluation_pampa.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/FCNN-1/evaluation_pampa.csv"]]
for csv_file in memb_csv_files:
    df = concat_metric_files(csv_file)
    # print (df.head())
    metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
    levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
    print (Path(csv_file[0]).name)
    print (levene_variance_df)
    metric_ls = ['PearsonR', 'RMSE', 'MAE']
    split_ls = ['scaffold', 'butina'] #, 'random']
    for split in split_ls:
        make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_pampa_ER_protomers", common_prefix="pampa-biogen-ER")
        make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_pampa_ER_protomers", common_prefix="pampa-biogen-ER")
# Out:
# evaluation_pampa.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2       0.006918  28089.563490
# 1     butina         RMSE       0.001192   6174.380978
# 2     butina          MAE       0.063679     18.370221
# 3     butina     PearsonR       0.000211     55.311804
# 4     butina  SpearmanRho       0.000010     10.675837
# 5     random           R2       0.097536      4.222477
# 6     random         RMSE       0.001781      6.596671
# 7     random          MAE       0.000044      5.479651
# 8     random     PearsonR       0.261520      2.385431
# 9     random  SpearmanRho       0.410641      2.348710
# 10  scaffold           R2       0.007692     15.631936
# 11  scaffold         RMSE       0.574568      1.788712
# 12  scaffold          MAE       0.070243      4.144817
# 13  scaffold     PearsonR       0.000761      9.780621
# 14  scaffold  SpearmanRho       0.574355      3.689846

# %%
memb_csv_files = [["../ml-modeling-ER_lgfe_biogen_base/evaluation/XGBoost/evaluation_popc_chol.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/XGBoost/evaluation_popc_chol.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/LightGBM/evaluation_popc_chol.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/LightGBM/evaluation_popc_chol.csv",
                  "../ml-modeling-ER_lgfe_biogen_base/evaluation/FCNN-1/evaluation_popc_chol.csv",
                   "../ml-modeling-ER_lgfe_biogen_extended_with_protomers/evaluation/FCNN-1/evaluation_popc_chol.csv"]]
for csv_file in memb_csv_files:
    df = concat_metric_files(csv_file)
    # print (df.head())
    metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
    levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
    print (Path(csv_file[0]).name)
    print (levene_variance_df)
    metric_ls = ['PearsonR', 'RMSE', 'MAE']
    split_ls = ['scaffold', 'butina'] #, 'random']
    for split in split_ls:
        make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_popc_chol_ER_protomers", common_prefix="popc_chol-biogen-ER")
        make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir="./implicit_vs_explicit_popc_chol_ER_protomers", common_prefix="popc_chol-biogen-ER")
# Out:
# evaluation_popc_chol.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2   4.630028e-03      6.933936
# 1     butina         RMSE   8.925980e-09      9.608003
# 2     butina          MAE   2.480377e-05      6.034180
# 3     butina     PearsonR   4.920850e-03      3.635915
# 4     butina  SpearmanRho   2.166135e-04      8.722652
# 5     random           R2   3.993646e-01      2.905224
# 6     random         RMSE   4.993350e-01      2.443314
# 7     random          MAE   7.853313e-01      1.517307
# 8     random     PearsonR   7.212365e-01      1.509984
# 9     random  SpearmanRho   4.306342e-01      2.565368
# 10  scaffold           R2   1.378287e-05     13.820580
# 11  scaffold         RMSE   4.232965e-01      3.653319
# 12  scaffold          MAE   1.085956e-02      4.277535
# 13  scaffold     PearsonR   1.172756e-05      6.829700
# 14  scaffold  SpearmanRho   4.049657e-01      2.775069

# %% [markdown]
# #### Independent Datasets
# 1. MDCK-MDR1 systems

# %%
for independent_sm in ["MDCK-Hellinger", "MDCK-Irvine", "MDCK-MDR1-Hellinger", "MDCK-MDR1-QWang", "MDCK-MDR1-Summerfield", "cMdr1_KO_MDCK1-beran"]:
    memb_csv_files = [[f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_popc_chol.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_popc_chol.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_popc_chol.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_popc_chol.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_popc_chol.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_popc_chol.csv"]]
    for csv_file in memb_csv_files:
        df = concat_metric_files(csv_file)
        # print (df.head())
        metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
        levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
        print (Path(csv_file[0]).name)
        print (levene_variance_df)
        metric_ls = ['PearsonR', 'MAE','RMSE']
        split_ls = ['scaffold', 'butina'] #, 'random']
        for split in split_ls:
            make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_popc_chol_sm/{independent_sm}/", common_prefix="popc_chol-biogen-P_app")
            make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_popc_chol_sm/{independent_sm}/", common_prefix="popc_chol-biogen-P_app")
# Out:
# evaluation_popc_chol.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2       0.034606      3.718418
# 1     butina         RMSE       0.079363      3.265405
# 2     butina          MAE       0.067942      3.454192
# 3     butina     PearsonR       0.075672      2.710128
# 4     butina  SpearmanRho       0.669432      2.946955
# 5     random           R2       0.079797      5.422519
# 6     random         RMSE       0.068627      4.616140
# 7     random          MAE       0.046205      5.043820
# 8     random     PearsonR       0.067351      4.142477
# 9     random  SpearmanRho       0.037797      4.498715
# 10  scaffold           R2       0.485831      1.821451
# 11  scaffold         RMSE       0.674197      1.715069
# 12  scaffold          MAE       0.510705      1.953376
# 13  scaffold     PearsonR       0.022701     12.956908
# 14  scaffold  SpearmanRho       0.061258      6.894737
# evaluation_popc_chol.csv
# ...

# %%
for independent_sm in ["MDCK-Hellinger", "MDCK-Irvine", "MDCK-MDR1-Hellinger", "MDCK-MDR1-QWang", "MDCK-MDR1-Summerfield", "cMdr1_KO_MDCK1-beran"]:
    memb_csv_files = [[f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_pampa.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_pampa.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_pampa.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_pampa.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_pampa.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_pampa.csv"]]
    for csv_file in memb_csv_files:
        df = concat_metric_files(csv_file)
        # print (df.head())
        metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
        levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
        print (Path(csv_file[0]).name)
        print (levene_variance_df)
        metric_ls = ['PearsonR', 'MAE','RMSE']
        split_ls = ['scaffold', 'butina'] #, 'random']
        for split in split_ls:
            make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_pampa_sm/{independent_sm}/", common_prefix="pampa-biogen-P_app")
            make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_pampa_sm/{independent_sm}/", common_prefix="pampa-biogen-P_app")
# Out:
# evaluation_pampa.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2       0.223747      2.794007
# 1     butina         RMSE       0.229237      2.631998
# 2     butina          MAE       0.088482      3.152070
# 3     butina     PearsonR       0.089122     22.206362
# 4     butina  SpearmanRho       0.076485      4.120879
# 5     random           R2       0.004740      5.168329
# 6     random         RMSE       0.003092      6.058082
# 7     random          MAE       0.020193      5.808485
# 8     random     PearsonR       0.018219      9.499726
# 9     random  SpearmanRho       0.221487      5.669291
# 10  scaffold           R2       0.479585      3.271551
# 11  scaffold         RMSE       0.297884      3.678901
# 12  scaffold          MAE       0.386552      3.439413
# 13  scaffold     PearsonR       0.215971    321.337208
# 14  scaffold  SpearmanRho       0.002722     18.333333
# evaluation_pampa.csv
# ...

# %%
for independent_sm in ["MDCK-Hellinger", "MDCK-Irvine", "MDCK-MDR1-Hellinger", "MDCK-MDR1-QWang", "MDCK-MDR1-Summerfield", "cMdr1_KO_MDCK1-beran"]:
    memb_csv_files = [[f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_bbb.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/XGBoost_independent_sm_{independent_sm}/evaluation_bbb.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_bbb.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/LightGBM_independent_sm_{independent_sm}/evaluation_bbb.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_base/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_bbb.csv",
                    f"../ml-modeling-P_app_lgfe_biogen_extended_with_protomers/evaluation/FCNN_independent_sm-1_{independent_sm}/evaluation_bbb.csv"]]
    for csv_file in memb_csv_files:
        df = concat_metric_files(csv_file)
        # print (df.head())
        metric_ls_full = ['R2', 'RMSE', 'MAE', 'PearsonR', 'SpearmanRho']
        levene_variance_df = variance_analysis_by_split(df, metric_ls_full)
        print (Path(csv_file[0]).name)
        print (levene_variance_df)
        metric_ls = ['PearsonR', 'MAE','RMSE']
        split_ls = ['scaffold', 'butina'] #, 'random']
        for split in split_ls:
            make_boxplots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_bbb_sm/{independent_sm}/", common_prefix="bbb-biogen-P_app")
            make_sign_plots_nonparametric(df.query("split == '" + split + "'"), metric_ls, prefix=split, outdir=f"./independent_bbb_sm/{independent_sm}/", common_prefix="bbb-biogen-P_app")
# Out:
# evaluation_bbb.csv
#        split       metric  levene_pvalue  max_over_min
# 0     butina           R2       0.030039      3.622597
# 1     butina         RMSE       0.012104      4.134976
# 2     butina          MAE       0.017574      4.449379
# 3     butina     PearsonR       0.181650     22.423617
# 4     butina  SpearmanRho       0.026227     11.700000
# 5     random           R2       0.104661      3.885869
# 6     random         RMSE       0.065865      5.498785
# 7     random          MAE       0.006727      7.326323
# 8     random     PearsonR       0.112042     16.544580
# 9     random  SpearmanRho       0.257084      3.925234
# 10  scaffold           R2       0.060537      2.552548
# 11  scaffold         RMSE       0.025331      2.841221
# 12  scaffold          MAE       0.003657      3.387263
# 13  scaffold     PearsonR       0.029825     17.070112
# 14  scaffold  SpearmanRho       0.403326      5.338983
# evaluation_bbb.csv
# ...
